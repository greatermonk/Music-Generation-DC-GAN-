# %%
# %pip install wandb music21
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.21.0)
# Requirement already satisfied: music21 in /usr/local/lib/python3.11/dist-packages (9.3.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.2.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from wandb) (24.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.14.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from music21) (5.2.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from music21) (1.5.1)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.11/dist-packages (from music21) (4.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from music21) (3.10.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from music21) (10.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from music21) (2.0.2)
# Requirement already satisfied: webcolors>=1.5 in /usr/local/lib/python3.11/dist-packages (from music21) (24.11.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.7.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (2.9.0.post0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->music21) (1.17.0)

# %% [markdown]
# # Import Necessary libraries
#
# - **numpy** (required)
# - **tensorflow** (required)
# - **wandb (optional)**
# - **matplotlib** (optional, may required if generating new scores)
#
# - **music21** (Required for constructing `midi` files)
#
# **Custom utility functions:**
#
# * notes_to_midi()
# * draw_score()

# %%
import os                # creating, writing & storing files and directories
import numpy as np
import tensorflow as tf
import wandb
import keras
from matplotlib import pyplot as plt
import music21

from keras import (
    layers,
    models,
    optimizers,
    callbacks,
    initializers,
    metrics
)
from tensorflow.python.ops.linalg.linalg_impl import sqrtm
from wandb.integration.keras import WandbMetricsLogger
from google.colab import drive

# %%
drive.mount("/content/drive")
dataset_path = "/content/drive/MyDrive/DC_GAN_MUSIC/Jsb16thSeparated.npz"
model_checkpoint_path = "/content/drive/MyDrive/DC_GAN_MUSIC/model_checkpoints"
tf_logs_path = "/content/drive/MyDrive/DC_GAN_MUSIC/logs"
output_dir = "/content/drive/MyDrive/DC_GAN_MUSIC/output"
# Out:
# Mounted at /content/drive

# %%
def binarize_output(output_tensor):
    """
    :param output_tensor: A vector of shape (batch_size, bars, steps, pitches, tracks)
    :return: Position of the maximum pitch value from the tracks.
    """
    return np.argmax(output_tensor, axis=3)


def notes_to_midi(output, n_bars: int, n_tracks: int, steps_per_bar: int, filename: str):
    """
    :param output: An output tensor of shape (batch_size, bars, steps, pitches, tracks)
    :param n_bars: no of bars per score i.e (axis=1)
    :param n_tracks: no of tracks per score i.e (axis=4 or -1)
    :param steps_per_bar: no of steps per bar per score i.e (axis=2)
    :param filename: the path or the destination to write into (defaults to output_dir)
    :return: A constructed `.mid` file that you can listen to.
    """

    for scores in range(len(output)):
        max_pitches = binarize_output(output)
        midi_note_score =  max_pitches[scores].reshape(n_bars * steps_per_bar, n_tracks)

        parts = music21.stream.Score()
        parts.append(music21.tempo.MetronomeMark(number=66))
        for i in range(n_tracks):
            last_x = int(midi_note_score[:, i][0])
            note_stream = music21.stream.Part()
            duration = 0
            for pos, track in enumerate(midi_note_score[:, i]):
                x = int(track)
                if (x != last_x or pos % 4 == 0) and pos:
                    note = music21.note.Note(last_x)
                    note.duration = music21.duration.Duration(duration)
                    note_stream.append(note)
                    duration = 0
                last_x = x
                duration += .25
            note = music21.note.Note(last_x)
            note.duration = music21.duration.Duration(duration)
            note_stream.append(note)
            parts.append(note_stream)
       # os.makedirs(output_dir, exist_ok=True)
        parts.write("midi", fp=f"{output_dir}/{filename}_{scores}")



def draw_bar(data, score, bar, part):
    plt.imshow(
        data[score, bar, :, :, part].transpose([1, 0]),
        origin="lower",
        cmap=plt.get_cmap("jet"),
        vmin=-1,
        vmax=1
    )


def draw_score(data, score):
    """

    :param data: A tensor of shape (batch_size, bars, steps, pitches, tracks)
    :param score: The current score
    :return: A matplotlib pyplot of the generated score
    """
    num_bars, num_tracks = data.shape[1], data.shape[-1]

    fig, ax = plt.subplots(num_tracks, num_bars, figsize=(12, 8), sharex=True, sharey=True)
    fig.subplots_adjust(0, 0, .2, 1.5, 0, 0)
    plt.style.use('ggplot')

    for bar in range(num_bars):
        for track in range(num_tracks):
            if num_bars > 1:
                ax[track, bar].imshow(
                    data[score, bar, :, :, track].transpose([1, 0]),
                    origin="lower",
                    cmap=plt.get_cmap("jet")
                )

            else:
                ax[track].imshow(
                    data[score, bar, :, :, track].transpose([1, 0]),
                    origin="lower",
                    cmap=plt.get_cmap("Greys")
                )



def plot_score(data, title="Generated Score"):
    """
    Plots a multi-track musical score in a more aesthetic and helpful way.

    :param data: A tensor of shape (bars, steps, pitches, tracks)
    :param title: The title for the plot.
    """
    # --- 1. Prepare the data ---
    # The input 'data' is now expected to be a single score (bars, steps, pitches, tracks)
    score = data
    num_bars, num_steps, num_pitches, num_tracks = score.shape

    # Create a 2D piano roll for each track
    piano_rolls = []
    for track in range(num_tracks):
        # Reshape from (bars, steps, pitches) to (bars * steps, pitches)
        track_data = score[:, :, :, track].reshape(-1, num_pitches)
        piano_rolls.append(track_data.T) # Transpose to have pitches on y-axis and time on x-axis

    # Vertically concatenate the piano rolls for each track
    combined_roll = np.vstack(piano_rolls)


    # --- 2. Create the plot ---
    fig, ax = plt.subplots(figsize=(16, 8))
    plt.style.use('ggplot') # A dark theme often looks better

    # Use a perceptually uniform colormap like 'magma' or 'viridis'
    im = ax.imshow(
        combined_roll,
        aspect='auto',
        origin='lower',
        cmap=plt.get_cmap('magma'),
        interpolation='nearest' # Use 'nearest' to get sharp note edges
    )

    # --- 3. Add helpful labels and titles ---
    # Adjust y-ticks to represent tracks, accounting for concatenated piano rolls
    track_height = num_pitches
    ax.set_yticks([i * track_height + track_height / 2 for i in range(num_tracks)])
    ax.set_yticklabels([f'Track {i+1}' for i in range(num_tracks)])
    ax.set_ylabel("Instrument Tracks")

    # Set x-axis ticks to mark the beginning of each bar
    ax.set_xticks(np.arange(0, num_bars * num_steps, num_steps))
    ax.set_xticklabels([f'Bar {i+1}' for i in range(num_bars)])
    ax.set_xlabel("Time")
    ax.minorticks_on()

    fig.suptitle(title, fontsize=16)

    # --- 4. Clean up aesthetics ---
    # Add horizontal lines to separate tracks
    for i in range(num_tracks):
        ax.axhline(y=(i + 1) * track_height - 0.5, color='gray', linestyle='--', linewidth=0.5)


    # Remove the top and right spines for a cleaner look
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    plt.tight_layout(rect=[0, 0, 1, 0.96]) # Adjust layout to make space for the suptitle
    plt.show()

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: vedantgade2006 (vedantgade2006-secant) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
from google.colab import userdata
userdata.get('WANDB_API_KEY')

wandb.init(
    project='DC-GAN-Music',
    name="DC-GAN-Music",
    config={
        "z_dim": 32,
        "critic_steps": 5,
        "gp_weight": 10,
        "generator_lr": .001,
        "critic_lr": .001,
        "beta1": .5,
        "beta2": .9,
        "epochs": 5000,
        "batch_size": 64,
        "dataset": "JS Bach Chorale Dataset",
        "architecture": "GAN"
    }
)
# Out:
# wandb: Currently logged in as: vedantgade2006 (vedantgade2006-secant) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.1s)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20251002_162712-ww4t5tg4</code>
# Syncing run <strong><a href='https://wandb.ai/vedantgade2006-secant/DC-GAN-Music/runs/ww4t5tg4' target="_blank">DC-GAN-Music</a></strong> to <a href='https://wandb.ai/vedantgade2006-secant/DC-GAN-Music' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/vedantgade2006-secant/DC-GAN-Music' target="_blank">https://wandb.ai/vedantgade2006-secant/DC-GAN-Music</a>
#  View run at <a href='https://wandb.ai/vedantgade2006-secant/DC-GAN-Music/runs/ww4t5tg4' target="_blank">https://wandb.ai/vedantgade2006-secant/DC-GAN-Music/runs/ww4t5tg4</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/vedantgade2006-secant/DC-GAN-Music/runs/ww4t5tg4?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
#Define HyperParameter Constants
TRAIN_BATCH_SIZE = 64
N_BARS = 2               # NO OF BARS PER TRACK
N_STEPS_PER_BAR = 16     # NO OF TIME-STEPS PER BAR
MAX_PITCH = 83           # MAXIMUM MIDI PITCH USED
N_PITCHES = MAX_PITCH + 1
Z_DIM = 32               # DIMENSION OF THE LATENT SPACE

CRITIC_STEPS = 5
GP_WEIGHT = 10
CRITIC_LR = .0001
GENERATOR_LR = .0001
ADAM_BETA1 = .5
ADAM_BETA2 = .99
NUM_EPOCHS = 500
LOAD_MODEL = False

# %%
#DATASET_PATH='src/Jsb16thSeparated.npz'

with np.load(dataset_path, encoding="bytes", allow_pickle=True) as f:
    train_data = f['train']
    test_data =  f['test']


N_SONGS = len(train_data)
print(f"There are {N_SONGS} songs in train set.")
chorale = train_data[0]
N_BEATS, N_TRACKS = chorale.shape
print(f"{N_BEATS} beats and {N_TRACKS} tracks.")
print(f"\nTrain Chorale: 0")
print("\n", chorale[:10])


N_SONGS2 = len(test_data)
print(f"There are {N_SONGS} songs in test set.")
chorale2 = test_data[0]
N_BEATS, N_TRACKS = chorale2.shape
print(f"{N_BEATS} beats and {N_TRACKS} tracks.")
print(f"\nTest Chorale: 0")
print("\n", chorale2[:10])
# Out:
# There are 229 songs in train set.
# 192 beats and 4 tracks.
#
# Train Chorale: 0
#
#  [[74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [75. 70. 58. 55.]
#  [75. 70. 58. 55.]
#  [75. 70. 60. 55.]
#  [75. 70. 60. 55.]
#  [77. 69. 62. 50.]
#  [77. 69. 62. 50.]]
# There are 229 songs in test set.
# 228 beats and 4 tracks.
#
# Test Chorale: 0
#
#  [[65. 60. 57. 53.]
#  [65. 60. 57. 53.]
#  [65. 60. 57. 53.]
#  [65. 60. 57. 53.]
#  [72. 60. 55. 52.]
#  [72. 60. 55. 52.]
#  [70. 60. 55. 52.]
#  [70. 60. 55. 52.]
#  [69. 60. 53. 53.]
#  [69. 60. 53. 53.]]

# %%
two_bars = np.array([x[:(N_BARS * N_STEPS_PER_BAR)] for x in train_data])
two_bars = np.array(np.nan_to_num(two_bars, nan=MAX_PITCH), dtype=np.int32)
two_bars = two_bars.reshape([N_SONGS, N_BARS, N_STEPS_PER_BAR, N_TRACKS])
print(f"2 bars shape (no of songs * no of bars * steps per bar * no of tracks): {two_bars.shape}")

binary_data = np.eye(N_PITCHES)[two_bars]
#print(binary_data.shape)
#binary_data[binary_data == 0] = -1
binary_data = np.where(binary_data == 0, -1, binary_data)
#print(binary_data)
binary_data = binary_data.transpose([0, 1, 2, 4, 3])
#print(binary_data)
print(f"\nTransformed Train Binary data shape (songs * bars * steps * pitches, tracks):\n{binary_data.shape}")


# Pre-process Test & Validation subset to match train data.

two_bars_test = np.array([x[:(N_BARS * N_STEPS_PER_BAR)] for x in test_data])
two_bars_test = np.array(np.nan_to_num(two_bars_test, nan=MAX_PITCH), dtype=np.int32)
two_bars_test = two_bars_test.reshape([len(test_data), N_BARS, N_STEPS_PER_BAR, N_TRACKS])
print(f"\n2 bars shape (no of songs * no of bars * steps per bar * no of tracks): {two_bars_test.shape}")
test_binary_data = np.eye(N_PITCHES)[two_bars_test]
test_binary_data = np.where(test_binary_data == 0, -1, test_binary_data)
test_binary_data = test_binary_data.transpose([0, 1, 2, 4, 3])

print(f"\nTransformed Test Binary data shape (songs * bars * steps * pitches, tracks):\n{test_binary_data.shape}")
# Out:
# 2 bars shape (no of songs * no of bars * steps per bar * no of tracks): (229, 2, 16, 4)
#
# Transformed Train Binary data shape (songs * bars * steps * pitches, tracks):
# (229, 2, 16, 84, 4)
#
# 2 bars shape (no of songs * no of bars * steps per bar * no of tracks): (77, 2, 16, 4)
#
# Transformed Test Binary data shape (songs * bars * steps * pitches, tracks):
# (77, 2, 16, 84, 4)

# %%
# Convert the test set into a tensorflow dataset for validation and FID callback access.
dummy_y = tf.zeros(shape=len(test_binary_data), dtype=tf.float64)
validation_set = tf.data.Dataset.from_tensor_slices((test_binary_data,  dummy_y))
validation_set.batch(TRAIN_BATCH_SIZE)
list(validation_set.as_numpy_iterator())

# %%
# Define some helper functions for our GAN network
initializer = initializers.RandomNormal(mean=0.0, stddev=0.02)

def conv(x, f, k, s, p):
    """
    :param x: A tensor of shape (batch_size, num_bars, steps_per_bar, num_pitches, num_tracks).
    :param f: Number of filters.
    :param k: Defines the size of the convolutional filter that strides along the input data.
    :param s: How many strides (the no of data values across all dimensions) the kernel passes through.
    :param p: Padding used by the kernel, can be either of 'valid','same' or 'zeros'.
    ----
    :return: A 3d convoluted tensor using leaky relu as activation function.
    """
    x = layers.Conv3D(
        filters=f,
        kernel_size=k,
        strides=s,
        padding=p,
        kernel_initializer=initializer
    )(x)

    x = layers.LeakyReLU()(x)
    return x



def conv_t(x, f, k, s, a, p, bn):
    """
    :param x: A tensor of shape (batch_size, num_bars, steps_per_bar, num_pitches).
    :param f: Number of convolutional filters to use.
    :param k: Defines the size of the convolutional filter that strides along the input data.
    :param s: How many strides (the no of data values across all dimensions) the kernel passes through.
    :param a: Activation function to use can be either of relu or tanh (GAN relative).
    :param p: Padding used by the kernel, can be either of 'valid','same' or 'zeros'.
    :param bn: Whether to use batch normalization or not.
    :return:
    A 2d Convolution Transposed Tensor of shape (batch_size, num_bars, steps_per_bar, num_pitches).
    """
    x = layers.Conv2DTranspose(
        filters=f,
        kernel_size=k,
        padding=p,
        strides=s,
        kernel_initializer=initializer
    )(x)
    if bn:
        x = layers.BatchNormalization(momentum=.9)(x)
    x = layers.Activation(a)(x)
    return x

# %% [markdown]
# ## **Temporal Network**
#
# A Convolutional Network block used to generate an noise latent vector which will be used to handle chord & melody vectors of the Generator.
#
# ---
# ## **Bar Generator**
#
# Used to generate noise vectors sampled from the standard normal distribution N(0, 1).
# Converts Input noise vector of shape 128 (4x32) into a vector that's used by the generator input to generate each of chords, style, melody & groove for the score.

# %%
def temporal_network():
    input_layer = layers.Input(shape=(Z_DIM,), name="temp_input")
    x = layers.Reshape([1,1,Z_DIM], name="temp_reshape")(input_layer)
    x = conv_t(x, f=1024, k=(2,1), s=1, a="relu", p="valid", bn=True)
    x = conv_t(x, f=Z_DIM, k=1, s=1, a="relu", p="valid", bn=True)
    output_layer = layers.Reshape([N_BARS, Z_DIM])(x)
    return models.Model(inputs=input_layer, outputs=output_layer)


#temporal_network().summary()


def bar_generator():
    input_layer = layers.Input(shape=(Z_DIM*4,), name="bar_gen_input") # each of chord, style, groove & melody

    x = layers.Dense(1024)(input_layer)
    x = layers.BatchNormalization(momentum=.9)(x)
    x = layers.Activation("relu")(x)
    x = layers.Reshape([2, 1, 512])(x)

    x = conv_t(x, f=512 , k=(2,1) , s=(2,1) , a='relu',p='same', bn=True)
    x = conv_t(x, f=256 , k=(2,1) , s=(2,1) , a='relu',p='same', bn=True)
    x = conv_t(x, f=256 , k=(2,1) , s=(2,1) , a='relu',p='same', bn=True)
    x = conv_t(x, f=256 , k=(1,7) , s=(1,7) , a='relu',p='same', bn=True)
    x = conv_t(x, f=1, k=(1,12) , s=(1,12) , a='tanh',p='same', bn=False)
    output_layer = layers.Reshape([1, N_STEPS_PER_BAR, N_PITCHES, 1], name="BarGeneratorOutput")(x)

    return models.Model(inputs=input_layer, outputs=output_layer)


#bar_generator().summary()

# %%
def Generator():
    """
     :returns:
      A joined noise vector sampled from Z_DIM each consisting of [chords, style, melody, groove]:

     :input:

     - chords: Controls the general progression of music
              (rhythm, pitch, tempo, time_steps) across each bar & track.
              Useful for providing control over each bar and track.\n

     - style: Controls the overall behaviour of the song/music.
             Is applied throughout the musical sheet.

     - melody: Use to control track specific or bar relative features of
              melody including change in pitch value, time, quavers
              etc. Relative to each track.

     - groove: An additional noise vector of shape (n_tracks * z_dim).
              Used to control bar relative or track relative features
              and is applied throughout the music sheet altering the
              overall style of the track across the song.
    """

    chords_input = layers.Input(shape=(Z_DIM,), name="chords_input")
    style_input = layers.Input(shape=(Z_DIM,), name="style_input")
    melody_input = layers.Input(shape=(N_TRACKS, Z_DIM), name="melody_input")
    groove_input = layers.Input(shape=(N_TRACKS, Z_DIM), name="groove_input")

    # CHORDS -> TEMPORAL NETWORK
    chords_tempNetwork = temporal_network()
    chords_over_time = chords_tempNetwork(chords_input)  # [n_bars, z_dim]

    # MELODY -> TEMPORAL NETWORK
    melody_over_time = [None] * N_TRACKS  # list of n_tracks [n_bars z_dim] tensors
    melody_tempNetwork = [None] * N_TRACKS
    for track in range(N_TRACKS):
        melody_tempNetwork[track] = temporal_network()
        melody_track = layers.Lambda(lambda x, track = track: x[:, track, :])(
            melody_input
        )
        melody_over_time[track] = melody_tempNetwork[track](melody_track)

    # CREATE BAR GENERATOR FOR EACH TRACK
    barGen = [None] * N_TRACKS
    for track in range(N_TRACKS):
        barGen[track] = bar_generator()

    # CREATE OUTPUT FOR EVERY TRACK AND BAR
    bars_output = [None] * N_BARS
    c = [None] * N_BARS
    for bar in range(N_BARS):
        track_output = [None] * N_TRACKS

        c[bar] = layers.Lambda(lambda x, bar=bar: x[:, bar, :])(
            chords_over_time
        )  # [z_dim]
        s = style_input  # [z_dim]

        for track in range(N_TRACKS):
            melody = layers.Lambda(lambda x, bar=bar: x[:, bar, :])(
                melody_over_time[track]
            )  # [z_dim]
            groove = layers.Lambda(lambda x, track=track: x[:, track, :])(
                groove_input
            )  # [z_dim]

            z_input = layers.Concatenate(
                axis=1
            )([c[bar], s, melody, groove])

            track_output[track] = barGen[track](z_input)

        bars_output[bar] = layers.Concatenate(axis=-1)(track_output)

    generator_output = layers.Concatenate(axis=1)(bars_output)

    return models.Model(
        inputs=[chords_input, style_input, melody_input, groove_input],
        outputs=generator_output,
        name="generator_model"
    )

# %%
def Critic():
    critic_input = layers.Input(shape=(N_BARS, N_STEPS_PER_BAR, N_PITCHES, N_TRACKS), name="critic_input")

    x = conv(x=critic_input, f=128, k=(2,1,1), s=1, p="valid")
    x = conv(x=x, f=128, k=(N_BARS-1,1,1), s=1, p="valid")
    x = conv(x=x, f=128, k=(1,1,12), s=(1,1,12), p="same")
    x = conv(x=x, f=128, k=(1,1,7), s=(1,1,7), p="same")
    x = conv(x=x, f=128, k=(1,2,1), s=(1,2,1), p="same")
    x = conv(x=x, f=128, k=(1,2,1), s=(1,2,1), p="same")
    x = conv(x=x, f=256, k=(1,4,1), s=(1,2,1), p="same")
    x = conv(x=x, f=512, k=(1,3,1), s=(1,2,1), p="same")

    x = layers.Flatten(name="flatten")(x)
    x = layers.Dense(1024, kernel_initializer=initializer)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(.2)(x)

    critic_output = layers.Dense(1, activation=None, kernel_initializer=initializer)(x)

    return models.Model(inputs=critic_input, outputs=critic_output, name="critic_model")


Critic().summary()
# Out:
# Model: "critic_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ critic_input (InputLayer)       │ (None, 2, 16, 84, 4)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 1, 16, 84, 128) │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 1, 16, 84, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 1, 16, 84, 128) │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 1, 16, 84, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 1, 16, 7, 128)  │       196,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 1, 16, 7, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 1, 16, 1, 128)  │       114,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 1, 16, 1, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_4 (Conv3D)               │ (None, 1, 8, 1, 128)   │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 1, 8, 1, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 1, 4, 1, 128)   │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 1, 4, 1, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_6 (Conv3D)               │ (None, 1, 2, 1, 256)   │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 1, 2, 1, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_7 (Conv3D)               │ (None, 1, 1, 1, 512)   │       393,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 1, 1, 1, 512)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │         1,025 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,446,401 (5.52 MB)
#  Trainable params: 1,446,401 (5.52 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
class MuseGAN(models.Model):
    def __init__(self, generator_model, critic_model, latent_dim, critic_steps, gp_weight, **kwargs):
        super(MuseGAN, self).__init__(**kwargs)e
        self.generator_model = generator_model
        self.critic_model = critic_model
        self.latent_dim = latent_dim
        self.critic_steps = critic_steps
        self.gp_weight = gp_weight
        feature_layer = self.critic_model.get_layer('flatten').output # Capture the gradients before passing it to the dense layer.
        self.fid_feature_extractor = models.Model(
            inputs=self.critic_model.input,  # None, bars, steps, pitches, tracks
            outputs=feature_layer,
            name="fid_feature_extractor"
        )
        self.fid_metric = metrics.Mean(name="fid_score")
        self._built = False


    def compile(self, critic_optimizer, gen_optimizer):
        super(MuseGAN, self).compile()
        self.critic_optimizer = critic_optimizer
        self.gen_optimizer = gen_optimizer

        self.critic_wassertein_loss_metric = metrics.Mean(name="critic_wassertein_loss")
        self.critic_gradient_penalty_metric = metrics.Mean(name="critic_gradient_penalty")

        self.critic_loss_metric = metrics.Mean(name="critic_loss")
        self.gen_loss_metric = metrics.Mean(name="gen_loss")



    @property
    def metrics(self):
        super(MuseGAN, self).metrics
        return [
            self.critic_loss_metric,
            self.critic_wassertein_loss_metric,
            self.critic_gradient_penalty_metric,
            self.gen_loss_metric,
            self.fid_metric
        ]


    def gradient_penalty(self, batch_size, real_images, fake_images):
        """
        :usage:
        -------
        * The core idea of WGAN-GP is to force the norm (or magnitude) of this
        gradient to be exactly 1.
        * This ensures the critic's feedback is smooth and doesn't change too
        erratically.
        * The code calculates how far the gradient's norm is from 1, squares it,
        and this becomes the penalty.
        * This penalty is then added to the critic's loss, pushing the critic to
        learn a smoother scoring function.
        -------
        """
        alpha = tf.random.normal(shape=(batch_size, 1, 1, 1, 1), mean=0.0, stddev=1.0)

        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            predictions = self.critic_model(interpolated, training=True)

        gradients = gp_tape.gradient(predictions, [interpolated])[0]
        rms_norm = tf.sqrt(tf.reduce_sum(tf.square(gradients), axis=[1,2,3,4]))
        gp = tf.reduce_mean((rms_norm - 1.0) ** 2)
        return gp



    def calculate_fid(self, real_images, fake_images):
        '''
        Calculates the FID (Frechet Inception Distance) between generated & target samples.
        '''
        # Get the feature activations
        real_features = self.fid_feature_extractor.predict(real_images)
        fake_features = self.fid_feature_extractor.predict(fake_images)

        mu_real, sigma_real = np.mean(real_features, axis=0), np.cov(real_features, rowvar=False)
        mu_fake, sigma_fake = np.mean(fake_features, axis=0), np.cov(fake_features, rowvar=False)
        sum_sq_diff = np.sum((mu_real - mu_fake) ** 2.0)
        cov_sqrt = sqrtm(sigma_real.dot(sigma_fake))
        # Check for complex numbers and take the real part
        if np.iscomplexobj(cov_sqrt):
            cov_sqrt = cov_sqrt.real

        fid = sum_sq_diff + np.trace(sigma_real + sigma_fake - 2.0 * cov_sqrt)
        return fid


    def generate_random_latent_vectors(self, batch_size):
        return [
            tf.random.normal(shape=(batch_size, self.latent_dim)),
            tf.random.normal(shape=(batch_size, self.latent_dim)),
            tf.random.normal(shape=(batch_size, N_TRACKS, self.latent_dim)),
            tf.random.normal(shape=(batch_size, N_TRACKS, self.latent_dim))
        ]


    @tf.function(jit_compile=True)
    def train_step(self, real_images):
        batch_size = tf.shape(real_images)[0]

        # Build the optimizers on the first training step
        if not self._built:
            self.critic_optimizer.build(self.critic_model.trainable_variables)
            self.gen_optimizer.build(self.generator_model.trainable_variables)
            self._built = True

        for step in range(self.critic_steps):
            random_latent_vectors = self.generate_random_latent_vectors(batch_size)

            with tf.GradientTape() as tape:
                fake_images = self.generator_model(random_latent_vectors, training=True)
                fake_predictions = self.critic_model(fake_images, training=True)
                real_predictions = self.critic_model(real_images, training=True)

                c_wass_loss = tf.reduce_mean(fake_predictions) - tf.reduce_mean(real_predictions)
                gp = self.gradient_penalty(batch_size, real_images, fake_images)
                critic_loss = c_wass_loss + gp * self.gp_weight

            critic_gradients = tape.gradient(critic_loss, self.critic_model.trainable_variables)
            self.critic_optimizer.apply_gradients(zip(critic_gradients, self.critic_model.trainable_variables))

            random_latent_vectors = self.generate_random_latent_vectors(batch_size)

            with tf.GradientTape() as tape:
                fake_images = self.generator_model(random_latent_vectors, training=True)
                fake_predictions = self.critic_model(fake_images, training=True)
                gen_loss = -tf.reduce_mean(fake_predictions)

            gen_gradients = tape.gradient(gen_loss, self.generator_model.trainable_variables)
            self.gen_optimizer.apply_gradients(zip(gen_gradients, self.generator_model.trainable_variables))
            # Update metrics
            self.critic_loss_metric.update_state(critic_loss)
            self.critic_wassertein_loss_metric.update_state(c_wass_loss)
            self.critic_gradient_penalty_metric.update_state(gp)
            self.gen_loss_metric.update_state(gen_loss)

            return {m.name: m.result() for m in self.metrics}
        return None


    def generate_piano_roll(self, num_scores):
        crlv = tf.random.normal(shape=(num_scores, Z_DIM))
        srlv = tf.random.normal(shape=(num_scores, Z_DIM))
        mrlv = tf.random.normal(shape=(num_scores,N_TRACKS,Z_DIM))
        grlv = tf.random.normal(shape=(num_scores,N_TRACKS,Z_DIM))
        random_latent_vectors = [crlv,srlv,mrlv,grlv]

        return self.generator_model(random_latent_vectors).numpy()

# %%
class FIDCallback(keras.callbacks.Callback):
    def __init__(self, validation_data, num_samples=1024):
        super(FIDCallback, self).__init__()
        self.real_samples = validation_data.take(num_samples // TRAIN_BATCH_SIZE).map(lambda x, y: x)
        self.num_samples = num_samples


    def on_epoch_end(self, epoch, logs=None):
        super(FIDCallback, self).on_epoch_end(epoch, logs)
        print(f"\nCalculating FID score for epoch {epoch + 1}...")

        crlv = tf.random.normal(shape=(self.num_samples, Z_DIM))
        srlv = tf.random.normal(shape=(self.num_samples, Z_DIM))
        mrlv = tf.random.normal(shape=(self.num_samples, N_TRACKS, Z_DIM))
        grlv = tf.random.normal(shape=(self.num_samples, N_TRACKS, Z_DIM))
        random_latent_vectors = [crlv, srlv, mrlv, grlv]
        fake_music = self.model.generator_model.predict(random_latent_vectors)


        real_music_list = list(self.real_samples.as_numpy_iterator())
        real_music = np.concatenate(real_music_list, axis=0)
        # Ensure we have the same number of samples
        num_to_use = min(len(real_music), len(fake_music))

        # Reshape real_music to include the N_BARS dimension if it's missing
        if real_music.ndim == 4:
            real_music = real_music.reshape(-1, N_BARS, N_STEPS_PER_BAR, N_PITCHES, N_TRACKS)


        fid_score = self.model.calculate_fid(
            real_music[:num_to_use],
            fake_music[:num_to_use]
        )
        print(f"FID Score: {fid_score:.4f}")

        self.model.fid_metric.update_state(fid_score)
        if wandb.run:
            wandb.log({"epoch_fid_score": fid_score}, commit=False)  # commit=False to log with other epoch metrics

# %%
gen_model = Generator()
critic_model = Critic()

dc_gan = MuseGAN(
    generator_model=gen_model,
    critic_model=critic_model,
    latent_dim=Z_DIM,
    critic_steps=CRITIC_STEPS,
    gp_weight=GP_WEIGHT
)

if LOAD_MODEL:
    os.makedirs(model_checkpoint_path, exist_ok=True)
    model_weights_location = os.path.join(model_checkpoint_path, "dc_gan_weights.ckpt")
    dc_gan.load_weights(model_weights_location)


dc_gan.compile(
    critic_optimizer=optimizers.Adam(
        learning_rate=CRITIC_LR,
        beta_1=ADAM_BETA1,
        beta_2=ADAM_BETA2
    ),
    gen_optimizer=optimizers.Adam(
        learning_rate=GENERATOR_LR,
        beta_1=ADAM_BETA1,
        beta_2=ADAM_BETA2
    )
)

# %%
class MusicGen(callbacks.Callback):
    def __init__(self, num_scores):
        super(MusicGen, self).__init__()
        self.num_scores = num_scores

    def on_epoch_end(self, epoch, logs=None):
        super(MusicGen, self).on_epoch_end(epoch, logs)
        if epoch % 1 == 0:
            generated_music = self.model.generate_piano_roll(self.num_scores)
            notes_to_midi(
                generated_music,
                N_BARS,
                N_TRACKS,
                N_STEPS_PER_BAR,
                filename="output_" + str(epoch).zfill(4)
            )

# %%
# Define CallBacks to Use:
music_gen_callback = MusicGen(1)
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_path, "model.keras"),
    save_freq=10,
    verbose=0
)
#os.makedirs(tf_logs_path, exist_ok=True)
tensorboard_callback = callbacks.TensorBoard(log_dir=tf_logs_path)
wndb_callback = WandbMetricsLogger()
fid_callback = FIDCallback(validation_data=validation_set)

# %%
history = dc_gan.fit(
    binary_data,
    epochs=NUM_EPOCHS,
    batch_size=TRAIN_BATCH_SIZE,
    callbacks=[model_checkpoint_callback, tensorboard_callback, music_gen_callback, fid_callback, wndb_callback]
)
# exit wandb
wandb.finish()
# Out:
# Epoch 1/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - critic_gradient_penalty: 1.0000 - critic_loss: 9.9999 - critic_wassertein_loss: -1.0504e-05 - fid_score: 0.0000e+00 - gen_loss: 1.5863e-04
# Calculating FID score for epoch 1...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 680ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 131s 14s/step - critic_gradient_penalty: 1.0000 - critic_loss: 9.9999 - critic_wassertein_loss: -1.3100e-05 - fid_score: 0.0000e+00 - gen_loss: 1.6621e-04
# Epoch 2/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - critic_gradient_penalty: 1.0000 - critic_loss: 9.9997 - critic_wassertein_loss: -1.8716e-04 - fid_score: 0.0000e+00 - gen_loss: 3.4681e-04
# Calculating FID score for epoch 2...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 1.0000 - critic_loss: 9.9996 - critic_wassertein_loss: -2.1201e-04 - fid_score: 0.0000e+00 - gen_loss: 3.5410e-04
# Epoch 3/500
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 1s 460ms/step - critic_gradient_penalty: 1.0000 - critic_loss: 9.9986 - critic_wassertein_loss: -0.0011 - fid_score: 0.0000e+00 - gen_loss: 7.5407e-04
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py:107: UserWarning: You are saving a model that has not yet been built. It might not contain any weights yet. Consider building the model first by calling it on some data.
#   return saving_lib.save_model(model, filepath)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - critic_gradient_penalty: 0.9999 - critic_loss: 9.9973 - critic_wassertein_loss: -0.0022 - fid_score: 0.0000e+00 - gen_loss: 0.0014
# Calculating FID score for epoch 3...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.9999 - critic_loss: 9.9970 - critic_wassertein_loss: -0.0024 - fid_score: 0.0000e+00 - gen_loss: 0.0016
# Epoch 4/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - critic_gradient_penalty: 0.9996 - critic_loss: 9.9764 - critic_wassertein_loss: -0.0198 - fid_score: 0.0000e+00 - gen_loss: 0.0082
# Calculating FID score for epoch 4...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.9996 - critic_loss: 9.9741 - critic_wassertein_loss: -0.0217 - fid_score: 0.0000e+00 - gen_loss: 0.0086
# Epoch 5/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - critic_gradient_penalty: 0.9969 - critic_loss: 9.8422 - critic_wassertein_loss: -0.1264 - fid_score: 0.0000e+00 - gen_loss: -0.0051
# Calculating FID score for epoch 5...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - critic_gradient_penalty: 0.9965 - critic_loss: 9.8277 - critic_wassertein_loss: -0.1373 - fid_score: 0.0000e+00 - gen_loss: -0.0105
# Epoch 6/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - critic_gradient_penalty: 0.9722 - critic_loss: 8.8938 - critic_wassertein_loss: -0.8281 - fid_score: 0.0000e+00 - gen_loss: -0.5448
# Calculating FID score for epoch 6...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.9693 - critic_loss: 8.7888 - critic_wassertein_loss: -0.9043 - fid_score: 0.0000e+00 - gen_loss: -0.6244
# Epoch 7/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - critic_gradient_penalty: 0.8097 - critic_loss: 3.2858 - critic_wassertein_loss: -4.8107 - fid_score: 0.0000e+00 - gen_loss: -6.2717
# Calculating FID score for epoch 7...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 0.7943 - critic_loss: 2.7716 - critic_wassertein_loss: -5.1717 - fid_score: 0.0000e+00 - gen_loss: -6.9488
# Epoch 8/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - critic_gradient_penalty: 0.2416 - critic_loss: -18.8908 - critic_wassertein_loss: -21.3068 - fid_score: 0.0000e+00 - gen_loss: -43.9046
# Calculating FID score for epoch 8...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.2244 - critic_loss: -20.3591 - critic_wassertein_loss: -22.6027 - fid_score: 0.0000e+00 - gen_loss: -47.4610
# Epoch 9/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - critic_gradient_penalty: 1.4752 - critic_loss: -48.5878 - critic_wassertein_loss: -63.3393 - fid_score: 0.0000e+00 - gen_loss: -155.2944
# Calculating FID score for epoch 9...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 1.6045 - critic_loss: -48.2627 - critic_wassertein_loss: -64.3072 - fid_score: 0.0000e+00 - gen_loss: -156.5906
# Epoch 10/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - critic_gradient_penalty: 1.7796 - critic_loss: -39.9316 - critic_wassertein_loss: -57.7274 - fid_score: 0.0000e+00 - gen_loss: -149.9933
# Calculating FID score for epoch 10...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 1.7316 - critic_loss: -39.6364 - critic_wassertein_loss: -56.9524 - fid_score: 0.0000e+00 - gen_loss: -149.8770
# Epoch 11/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - critic_gradient_penalty: 1.1460 - critic_loss: -32.7911 - critic_wassertein_loss: -44.2510 - fid_score: 0.0000e+00 - gen_loss: -151.6073
# Calculating FID score for epoch 11...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - critic_gradient_penalty: 1.1442 - critic_loss: -32.5780 - critic_wassertein_loss: -44.0196 - fid_score: 0.0000e+00 - gen_loss: -151.5766
# Epoch 12/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - critic_gradient_penalty: 0.9487 - critic_loss: -27.5021 - critic_wassertein_loss: -36.9890 - fid_score: 0.0000e+00 - gen_loss: -147.8862
# Calculating FID score for epoch 12...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.9380 - critic_loss: -27.3327 - critic_wassertein_loss: -36.7124 - fid_score: 0.0000e+00 - gen_loss: -147.6939
# Epoch 13/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 639ms/step - critic_gradient_penalty: 0.7219 - critic_loss: -23.0198 - critic_wassertein_loss: -30.2392 - fid_score: 0.0000e+00 - gen_loss: -143.0003
# Calculating FID score for epoch 13...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.7151 - critic_loss: -22.9917 - critic_wassertein_loss: -30.1428 - fid_score: 0.0000e+00 - gen_loss: -142.8852
# Epoch 14/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - critic_gradient_penalty: 0.6125 - critic_loss: -21.0040 - critic_wassertein_loss: -27.1292 - fid_score: 0.0000e+00 - gen_loss: -142.1790
# Calculating FID score for epoch 14...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - critic_gradient_penalty: 0.6089 - critic_loss: -20.8160 - critic_wassertein_loss: -26.9049 - fid_score: 0.0000e+00 - gen_loss: -142.0759
# Epoch 15/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - critic_gradient_penalty: 0.4673 - critic_loss: -17.6297 - critic_wassertein_loss: -22.3027 - fid_score: 0.0000e+00 - gen_loss: -137.4947
# Calculating FID score for epoch 15...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.4633 - critic_loss: -17.5071 - critic_wassertein_loss: -22.1397 - fid_score: 0.0000e+00 - gen_loss: -137.3139
# Epoch 16/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - critic_gradient_penalty: 0.3642 - critic_loss: -15.9293 - critic_wassertein_loss: -19.5710 - fid_score: 0.0000e+00 - gen_loss: -134.2508
# Calculating FID score for epoch 16...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 0.3633 - critic_loss: -15.8218 - critic_wassertein_loss: -19.4550 - fid_score: 0.0000e+00 - gen_loss: -134.2089
# Epoch 17/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - critic_gradient_penalty: 0.3227 - critic_loss: -14.2200 - critic_wassertein_loss: -17.4468 - fid_score: 0.0000e+00 - gen_loss: -132.5751
# Calculating FID score for epoch 17...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.3206 - critic_loss: -14.1735 - critic_wassertein_loss: -17.3796 - fid_score: 0.0000e+00 - gen_loss: -132.4785
# Epoch 18/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - critic_gradient_penalty: 0.2757 - critic_loss: -12.7819 - critic_wassertein_loss: -15.5389 - fid_score: 0.0000e+00 - gen_loss: -130.9686
# Calculating FID score for epoch 18...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.2735 - critic_loss: -12.7225 - critic_wassertein_loss: -15.4571 - fid_score: 0.0000e+00 - gen_loss: -130.9087
# Epoch 19/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - critic_gradient_penalty: 0.2388 - critic_loss: -12.2038 - critic_wassertein_loss: -14.5917 - fid_score: 0.0000e+00 - gen_loss: -129.7236
# Calculating FID score for epoch 19...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.2383 - critic_loss: -12.1117 - critic_wassertein_loss: -14.4947 - fid_score: 0.0000e+00 - gen_loss: -129.6801
# Epoch 20/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - critic_gradient_penalty: 0.2076 - critic_loss: -10.6912 - critic_wassertein_loss: -12.7668 - fid_score: 0.0000e+00 - gen_loss: -127.1234
# Calculating FID score for epoch 20...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.2054 - critic_loss: -10.6129 - critic_wassertein_loss: -12.6667 - fid_score: 0.0000e+00 - gen_loss: -126.9676
# Epoch 21/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - critic_gradient_penalty: 0.1625 - critic_loss: -9.8613 - critic_wassertein_loss: -11.4865 - fid_score: 0.0000e+00 - gen_loss: -124.3784
# Calculating FID score for epoch 21...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.1625 - critic_loss: -9.8540 - critic_wassertein_loss: -11.4788 - fid_score: 0.0000e+00 - gen_loss: -124.4009
# Epoch 22/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - critic_gradient_penalty: 0.1552 - critic_loss: -9.0257 - critic_wassertein_loss: -10.5775 - fid_score: 0.0000e+00 - gen_loss: -124.1762
# Calculating FID score for epoch 22...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 0.1542 - critic_loss: -9.0135 - critic_wassertein_loss: -10.5553 - fid_score: 0.0000e+00 - gen_loss: -124.0652
# Epoch 23/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - critic_gradient_penalty: 0.1345 - critic_loss: -8.4092 - critic_wassertein_loss: -9.7545 - fid_score: 0.0000e+00 - gen_loss: -122.3892
# Calculating FID score for epoch 23...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.1340 - critic_loss: -8.3893 - critic_wassertein_loss: -9.7289 - fid_score: 0.0000e+00 - gen_loss: -122.3648
# Epoch 24/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - critic_gradient_penalty: 0.1229 - critic_loss: -8.2441 - critic_wassertein_loss: -9.4729 - fid_score: 0.0000e+00 - gen_loss: -121.0329
# Calculating FID score for epoch 24...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.1220 - critic_loss: -8.2300 - critic_wassertein_loss: -9.4501 - fid_score: 0.0000e+00 - gen_loss: -121.0248
# Epoch 25/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - critic_gradient_penalty: 0.1073 - critic_loss: -7.2023 - critic_wassertein_loss: -8.2752 - fid_score: 0.0000e+00 - gen_loss: -120.6093
# Calculating FID score for epoch 25...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.1067 - critic_loss: -7.1935 - critic_wassertein_loss: -8.2609 - fid_score: 0.0000e+00 - gen_loss: -120.5130
# Epoch 26/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - critic_gradient_penalty: 0.0917 - critic_loss: -6.5206 - critic_wassertein_loss: -7.4377 - fid_score: 0.0000e+00 - gen_loss: -117.5369
# Calculating FID score for epoch 26...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - critic_gradient_penalty: 0.0910 - critic_loss: -6.4859 - critic_wassertein_loss: -7.3955 - fid_score: 0.0000e+00 - gen_loss: -117.3887
# Epoch 27/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - critic_gradient_penalty: 0.0726 - critic_loss: -6.6285 - critic_wassertein_loss: -7.3541 - fid_score: 0.0000e+00 - gen_loss: -115.6140
# Calculating FID score for epoch 27...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0732 - critic_loss: -6.6078 - critic_wassertein_loss: -7.3397 - fid_score: 0.0000e+00 - gen_loss: -115.7807
# Epoch 28/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - critic_gradient_penalty: 0.0765 - critic_loss: -6.2472 - critic_wassertein_loss: -7.0118 - fid_score: 0.0000e+00 - gen_loss: -116.5854
# Calculating FID score for epoch 28...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0765 - critic_loss: -6.2269 - critic_wassertein_loss: -6.9915 - fid_score: 0.0000e+00 - gen_loss: -116.6029
# Epoch 29/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - critic_gradient_penalty: 0.0696 - critic_loss: -6.1912 - critic_wassertein_loss: -6.8877 - fid_score: 0.0000e+00 - gen_loss: -115.8951
# Calculating FID score for epoch 29...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.0697 - critic_loss: -6.1294 - critic_wassertein_loss: -6.8259 - fid_score: 0.0000e+00 - gen_loss: -115.9098
# Epoch 30/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - critic_gradient_penalty: 0.0607 - critic_loss: -5.5725 - critic_wassertein_loss: -6.1793 - fid_score: 0.0000e+00 - gen_loss: -114.7862
# Calculating FID score for epoch 30...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - critic_gradient_penalty: 0.0605 - critic_loss: -5.5490 - critic_wassertein_loss: -6.1545 - fid_score: 0.0000e+00 - gen_loss: -114.7745
# Epoch 31/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - critic_gradient_penalty: 0.0533 - critic_loss: -5.1739 - critic_wassertein_loss: -5.7070 - fid_score: 0.0000e+00 - gen_loss: -113.7207
# Calculating FID score for epoch 31...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 0.0532 - critic_loss: -5.1593 - critic_wassertein_loss: -5.6908 - fid_score: 0.0000e+00 - gen_loss: -113.6721
# Epoch 32/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - critic_gradient_penalty: 0.0507 - critic_loss: -4.7905 - critic_wassertein_loss: -5.2978 - fid_score: 0.0000e+00 - gen_loss: -112.3911
# Calculating FID score for epoch 32...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0503 - critic_loss: -4.7811 - critic_wassertein_loss: -5.2839 - fid_score: 0.0000e+00 - gen_loss: -112.3558
# Epoch 33/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - critic_gradient_penalty: 0.0401 - critic_loss: -4.1225 - critic_wassertein_loss: -4.5235 - fid_score: 0.0000e+00 - gen_loss: -109.9958
# Calculating FID score for epoch 33...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - critic_gradient_penalty: 0.0398 - critic_loss: -4.1760 - critic_wassertein_loss: -4.5738 - fid_score: 0.0000e+00 - gen_loss: -109.9547
# Epoch 34/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - critic_gradient_penalty: 0.0383 - critic_loss: -3.9718 - critic_wassertein_loss: -4.3545 - fid_score: 0.0000e+00 - gen_loss: -109.7881
# Calculating FID score for epoch 34...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0381 - critic_loss: -3.9495 - critic_wassertein_loss: -4.3308 - fid_score: 0.0000e+00 - gen_loss: -109.7175
# Epoch 35/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - critic_gradient_penalty: 0.0310 - critic_loss: -4.1884 - critic_wassertein_loss: -4.4983 - fid_score: 0.0000e+00 - gen_loss: -107.8234
# Calculating FID score for epoch 35...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - critic_gradient_penalty: 0.0311 - critic_loss: -4.1678 - critic_wassertein_loss: -4.4791 - fid_score: 0.0000e+00 - gen_loss: -107.8444
# Epoch 36/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - critic_gradient_penalty: 0.0327 - critic_loss: -3.8892 - critic_wassertein_loss: -4.2164 - fid_score: 0.0000e+00 - gen_loss: -107.6083
# Calculating FID score for epoch 36...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - critic_gradient_penalty: 0.0327 - critic_loss: -3.8755 - critic_wassertein_loss: -4.2027 - fid_score: 0.0000e+00 - gen_loss: -107.6158
# Epoch 37/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - critic_gradient_penalty: 0.0266 - critic_loss: -3.3381 - critic_wassertein_loss: -3.6045 - fid_score: 0.0000e+00 - gen_loss: -105.4647
# Calculating FID score for epoch 37...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0265 - critic_loss: -3.3465 - critic_wassertein_loss: -3.6110 - fid_score: 0.0000e+00 - gen_loss: -105.4375
# Epoch 38/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 651ms/step - critic_gradient_penalty: 0.0253 - critic_loss: -3.7959 - critic_wassertein_loss: -4.0489 - fid_score: 0.0000e+00 - gen_loss: -105.8607
# Calculating FID score for epoch 38...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0256 - critic_loss: -3.7782 - critic_wassertein_loss: -4.0341 - fid_score: 0.0000e+00 - gen_loss: -105.9062
# Epoch 39/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - critic_gradient_penalty: 0.0278 - critic_loss: -3.7404 - critic_wassertein_loss: -4.0189 - fid_score: 0.0000e+00 - gen_loss: -106.3563
# Calculating FID score for epoch 39...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0278 - critic_loss: -3.7315 - critic_wassertein_loss: -4.0095 - fid_score: 0.0000e+00 - gen_loss: -106.3929
# Epoch 40/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - critic_gradient_penalty: 0.0295 - critic_loss: -3.5682 - critic_wassertein_loss: -3.8635 - fid_score: 0.0000e+00 - gen_loss: -107.1141
# Calculating FID score for epoch 40...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0294 - critic_loss: -3.5512 - critic_wassertein_loss: -3.8456 - fid_score: 0.0000e+00 - gen_loss: -107.0925
# Epoch 41/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - critic_gradient_penalty: 0.0216 - critic_loss: -2.8722 - critic_wassertein_loss: -3.0883 - fid_score: 0.0000e+00 - gen_loss: -104.1396
# Calculating FID score for epoch 41...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.0211 - critic_loss: -2.8865 - critic_wassertein_loss: -3.0973 - fid_score: 0.0000e+00 - gen_loss: -104.0244
# Epoch 42/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - critic_gradient_penalty: 0.0210 - critic_loss: -3.1944 - critic_wassertein_loss: -3.4041 - fid_score: 0.0000e+00 - gen_loss: -104.7474
# Calculating FID score for epoch 42...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 0.0211 - critic_loss: -3.1536 - critic_wassertein_loss: -3.3651 - fid_score: 0.0000e+00 - gen_loss: -104.6728
# Epoch 43/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - critic_gradient_penalty: 0.0171 - critic_loss: -2.8785 - critic_wassertein_loss: -3.0497 - fid_score: 0.0000e+00 - gen_loss: -102.2772
# Calculating FID score for epoch 43...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - critic_gradient_penalty: 0.0170 - critic_loss: -2.8908 - critic_wassertein_loss: -3.0613 - fid_score: 0.0000e+00 - gen_loss: -102.3463
# Epoch 44/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - critic_gradient_penalty: 0.0187 - critic_loss: -2.7513 - critic_wassertein_loss: -2.9381 - fid_score: 0.0000e+00 - gen_loss: -103.3246
# Calculating FID score for epoch 44...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - critic_gradient_penalty: 0.0186 - critic_loss: -2.7262 - critic_wassertein_loss: -2.9118 - fid_score: 0.0000e+00 - gen_loss: -103.2446
# Epoch 45/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - critic_gradient_penalty: 0.0125 - critic_loss: -2.2114 - critic_wassertein_loss: -2.3369 - fid_score: 0.0000e+00 - gen_loss: -99.9184
# Calculating FID score for epoch 45...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0122 - critic_loss: -2.1981 - critic_wassertein_loss: -2.3205 - fid_score: 0.0000e+00 - gen_loss: -99.8075
# Epoch 46/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - critic_gradient_penalty: 0.0108 - critic_loss: -2.4998 - critic_wassertein_loss: -2.6080 - fid_score: 0.0000e+00 - gen_loss: -99.6928
# Calculating FID score for epoch 46...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.0111 - critic_loss: -2.4973 - critic_wassertein_loss: -2.6086 - fid_score: 0.0000e+00 - gen_loss: -99.7706
# Epoch 47/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - critic_gradient_penalty: 0.0139 - critic_loss: -2.4296 - critic_wassertein_loss: -2.5684 - fid_score: 0.0000e+00 - gen_loss: -100.2308
# Calculating FID score for epoch 47...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 0.0139 - critic_loss: -2.4259 - critic_wassertein_loss: -2.5652 - fid_score: 0.0000e+00 - gen_loss: -100.2150
# Epoch 48/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 656ms/step - critic_gradient_penalty: 0.0124 - critic_loss: -2.3039 - critic_wassertein_loss: -2.4283 - fid_score: 0.0000e+00 - gen_loss: -98.7334
# Calculating FID score for epoch 48...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0123 - critic_loss: -2.2760 - critic_wassertein_loss: -2.3991 - fid_score: 0.0000e+00 - gen_loss: -98.6471
# Epoch 49/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - critic_gradient_penalty: 0.0091 - critic_loss: -2.1779 - critic_wassertein_loss: -2.2685 - fid_score: 0.0000e+00 - gen_loss: -97.2545
# Calculating FID score for epoch 49...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 0.0091 - critic_loss: -2.1573 - critic_wassertein_loss: -2.2485 - fid_score: 0.0000e+00 - gen_loss: -97.2450
# Epoch 50/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - critic_gradient_penalty: 0.0092 - critic_loss: -2.0314 - critic_wassertein_loss: -2.1238 - fid_score: 0.0000e+00 - gen_loss: -96.3614
# Calculating FID score for epoch 50...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0092 - critic_loss: -2.0391 - critic_wassertein_loss: -2.1307 - fid_score: 0.0000e+00 - gen_loss: -96.3725
# Epoch 51/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - critic_gradient_penalty: 0.0091 - critic_loss: -1.8130 - critic_wassertein_loss: -1.9044 - fid_score: 0.0000e+00 - gen_loss: -96.5730
# Calculating FID score for epoch 51...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.0090 - critic_loss: -1.8118 - critic_wassertein_loss: -1.9018 - fid_score: 0.0000e+00 - gen_loss: -96.4039
# Epoch 52/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - critic_gradient_penalty: 0.0069 - critic_loss: -1.7466 - critic_wassertein_loss: -1.8153 - fid_score: 0.0000e+00 - gen_loss: -94.7390
# Calculating FID score for epoch 52...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0069 - critic_loss: -1.8102 - critic_wassertein_loss: -1.8787 - fid_score: 0.0000e+00 - gen_loss: -94.9089
# Epoch 53/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - critic_gradient_penalty: 0.0152 - critic_loss: -2.2335 - critic_wassertein_loss: -2.3859 - fid_score: 0.0000e+00 - gen_loss: -98.4706
# Calculating FID score for epoch 53...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0150 - critic_loss: -2.1938 - critic_wassertein_loss: -2.3439 - fid_score: 0.0000e+00 - gen_loss: -98.3013
# Epoch 54/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - critic_gradient_penalty: 0.0068 - critic_loss: -1.9631 - critic_wassertein_loss: -2.0307 - fid_score: 0.0000e+00 - gen_loss: -95.0866
# Calculating FID score for epoch 54...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.0069 - critic_loss: -1.9817 - critic_wassertein_loss: -2.0502 - fid_score: 0.0000e+00 - gen_loss: -95.2250
# Epoch 55/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 904ms/step - critic_gradient_penalty: 0.0096 - critic_loss: -1.8454 - critic_wassertein_loss: -1.9417 - fid_score: 0.0000e+00 - gen_loss: -96.8953
# Calculating FID score for epoch 55...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - critic_gradient_penalty: 0.0095 - critic_loss: -1.8709 - critic_wassertein_loss: -1.9663 - fid_score: 0.0000e+00 - gen_loss: -96.8006
# Epoch 56/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - critic_gradient_penalty: 0.0091 - critic_loss: -1.9224 - critic_wassertein_loss: -2.0133 - fid_score: 0.0000e+00 - gen_loss: -96.9096
# Calculating FID score for epoch 56...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - critic_gradient_penalty: 0.0091 - critic_loss: -1.9022 - critic_wassertein_loss: -1.9931 - fid_score: 0.0000e+00 - gen_loss: -96.7926
# Epoch 57/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - critic_gradient_penalty: 0.0066 - critic_loss: -1.9634 - critic_wassertein_loss: -2.0295 - fid_score: 0.0000e+00 - gen_loss: -96.2027
# Calculating FID score for epoch 57...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0068 - critic_loss: -1.9723 - critic_wassertein_loss: -2.0405 - fid_score: 0.0000e+00 - gen_loss: -96.3620
# Epoch 58/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - critic_gradient_penalty: 0.0084 - critic_loss: -1.3708 - critic_wassertein_loss: -1.4553 - fid_score: 0.0000e+00 - gen_loss: -94.9184
# Calculating FID score for epoch 58...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - critic_gradient_penalty: 0.0081 - critic_loss: -1.3696 - critic_wassertein_loss: -1.4504 - fid_score: 0.0000e+00 - gen_loss: -94.7818
# Epoch 59/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - critic_gradient_penalty: 0.0045 - critic_loss: -1.9253 - critic_wassertein_loss: -1.9705 - fid_score: 0.0000e+00 - gen_loss: -94.9256
# Calculating FID score for epoch 59...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0048 - critic_loss: -1.9382 - critic_wassertein_loss: -1.9864 - fid_score: 0.0000e+00 - gen_loss: -95.1334
# Epoch 60/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - critic_gradient_penalty: 0.0097 - critic_loss: -1.6609 - critic_wassertein_loss: -1.7578 - fid_score: 0.0000e+00 - gen_loss: -96.4855
# Calculating FID score for epoch 60...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - critic_gradient_penalty: 0.0095 - critic_loss: -1.6563 - critic_wassertein_loss: -1.7510 - fid_score: 0.0000e+00 - gen_loss: -96.3608
# Epoch 61/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - critic_gradient_penalty: 0.0038 - critic_loss: -1.3014 - critic_wassertein_loss: -1.3391 - fid_score: 0.0000e+00 - gen_loss: -93.7845
# Calculating FID score for epoch 61...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - critic_gradient_penalty: 0.0038 - critic_loss: -1.3594 - critic_wassertein_loss: -1.3975 - fid_score: 0.0000e+00 - gen_loss: -94.0484
# Epoch 62/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - critic_gradient_penalty: 0.0092 - critic_loss: -1.7260 - critic_wassertein_loss: -1.8182 - fid_score: 0.0000e+00 - gen_loss: -96.6289
# Calculating FID score for epoch 62...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0090 - critic_loss: -1.7613 - critic_wassertein_loss: -1.8515 - fid_score: 0.0000e+00 - gen_loss: -96.6529
# Epoch 63/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - critic_gradient_penalty: 0.0076 - critic_loss: -1.2040 - critic_wassertein_loss: -1.2799 - fid_score: 0.0000e+00 - gen_loss: -95.0554
# Calculating FID score for epoch 63...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0072 - critic_loss: -1.2222 - critic_wassertein_loss: -1.2943 - fid_score: 0.0000e+00 - gen_loss: -94.9110
# Epoch 64/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - critic_gradient_penalty: 0.0039 - critic_loss: -1.4252 - critic_wassertein_loss: -1.4644 - fid_score: 0.0000e+00 - gen_loss: -94.9460
# Calculating FID score for epoch 64...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 0.0041 - critic_loss: -1.4184 - critic_wassertein_loss: -1.4598 - fid_score: 0.0000e+00 - gen_loss: -94.9946
# Epoch 65/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - critic_gradient_penalty: 0.0040 - critic_loss: -1.5501 - critic_wassertein_loss: -1.5904 - fid_score: 0.0000e+00 - gen_loss: -94.0033
# Calculating FID score for epoch 65...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - critic_gradient_penalty: 0.0040 - critic_loss: -1.5782 - critic_wassertein_loss: -1.6186 - fid_score: 0.0000e+00 - gen_loss: -94.0935
# Epoch 66/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - critic_gradient_penalty: 0.0078 - critic_loss: -1.5889 - critic_wassertein_loss: -1.6668 - fid_score: 0.0000e+00 - gen_loss: -96.7378
# Calculating FID score for epoch 66...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 0.0077 - critic_loss: -1.5870 - critic_wassertein_loss: -1.6643 - fid_score: 0.0000e+00 - gen_loss: -96.6753
# Epoch 67/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - critic_gradient_penalty: 0.0034 - critic_loss: -0.9818 - critic_wassertein_loss: -1.0156 - fid_score: 0.0000e+00 - gen_loss: -92.5121
# Calculating FID score for epoch 67...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0032 - critic_loss: -0.9657 - critic_wassertein_loss: -0.9980 - fid_score: 0.0000e+00 - gen_loss: -92.4500
# Epoch 68/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - critic_gradient_penalty: 0.0028 - critic_loss: -1.7618 - critic_wassertein_loss: -1.7902 - fid_score: 0.0000e+00 - gen_loss: -94.2111
# Calculating FID score for epoch 68...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0032 - critic_loss: -1.7349 - critic_wassertein_loss: -1.7668 - fid_score: 0.0000e+00 - gen_loss: -94.3626
# Epoch 69/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - critic_gradient_penalty: 0.0056 - critic_loss: -1.5392 - critic_wassertein_loss: -1.5948 - fid_score: 0.0000e+00 - gen_loss: -93.9956
# Calculating FID score for epoch 69...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 0.0054 - critic_loss: -1.5000 - critic_wassertein_loss: -1.5536 - fid_score: 0.0000e+00 - gen_loss: -93.9109
# Epoch 70/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - critic_gradient_penalty: 0.0048 - critic_loss: -2.1917 - critic_wassertein_loss: -2.2401 - fid_score: 0.0000e+00 - gen_loss: -96.8924
# Calculating FID score for epoch 70...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0053 - critic_loss: -2.2100 - critic_wassertein_loss: -2.2628 - fid_score: 0.0000e+00 - gen_loss: -97.1929
# Epoch 71/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - critic_gradient_penalty: 0.0104 - critic_loss: -1.0498 - critic_wassertein_loss: -1.1538 - fid_score: 0.0000e+00 - gen_loss: -94.5359
# Calculating FID score for epoch 71...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.0096 - critic_loss: -1.1114 - critic_wassertein_loss: -1.2070 - fid_score: 0.0000e+00 - gen_loss: -94.4791
# Epoch 72/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - critic_gradient_penalty: 0.0035 - critic_loss: -0.8927 - critic_wassertein_loss: -0.9280 - fid_score: 0.0000e+00 - gen_loss: -93.7070
# Calculating FID score for epoch 72...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0035 - critic_loss: -0.9186 - critic_wassertein_loss: -0.9535 - fid_score: 0.0000e+00 - gen_loss: -93.5946
# Epoch 73/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - critic_gradient_penalty: 0.0020 - critic_loss: -1.2758 - critic_wassertein_loss: -1.2961 - fid_score: 0.0000e+00 - gen_loss: -91.4051
# Calculating FID score for epoch 73...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0022 - critic_loss: -1.3494 - critic_wassertein_loss: -1.3717 - fid_score: 0.0000e+00 - gen_loss: -91.8984
# Epoch 74/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - critic_gradient_penalty: 0.0103 - critic_loss: -1.6738 - critic_wassertein_loss: -1.7772 - fid_score: 0.0000e+00 - gen_loss: -96.7835
# Calculating FID score for epoch 74...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0100 - critic_loss: -1.6380 - critic_wassertein_loss: -1.7376 - fid_score: 0.0000e+00 - gen_loss: -96.5045
# Epoch 75/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 791ms/step - critic_gradient_penalty: 0.0016 - critic_loss: -1.5145 - critic_wassertein_loss: -1.5310 - fid_score: 0.0000e+00 - gen_loss: -92.8126
# Calculating FID score for epoch 75...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - critic_gradient_penalty: 0.0019 - critic_loss: -1.5395 - critic_wassertein_loss: -1.5586 - fid_score: 0.0000e+00 - gen_loss: -93.2335
# Epoch 76/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - critic_gradient_penalty: 0.0073 - critic_loss: -1.6365 - critic_wassertein_loss: -1.7097 - fid_score: 0.0000e+00 - gen_loss: -96.2321
# Calculating FID score for epoch 76...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - critic_gradient_penalty: 0.0071 - critic_loss: -1.6464 - critic_wassertein_loss: -1.7172 - fid_score: 0.0000e+00 - gen_loss: -96.1481
# Epoch 77/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - critic_gradient_penalty: 0.0060 - critic_loss: -2.1041 - critic_wassertein_loss: -2.1642 - fid_score: 0.0000e+00 - gen_loss: -97.6835
# Calculating FID score for epoch 77...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0062 - critic_loss: -2.1027 - critic_wassertein_loss: -2.1647 - fid_score: 0.0000e+00 - gen_loss: -97.7486
# Epoch 78/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 625ms/step - critic_gradient_penalty: 0.0066 - critic_loss: -1.8750 - critic_wassertein_loss: -1.9408 - fid_score: 0.0000e+00 - gen_loss: -97.8885
# Calculating FID score for epoch 78...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0066 - critic_loss: -1.8977 - critic_wassertein_loss: -1.9634 - fid_score: 0.0000e+00 - gen_loss: -98.0126
# Epoch 79/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - critic_gradient_penalty: 0.0088 - critic_loss: -2.3615 - critic_wassertein_loss: -2.4491 - fid_score: 0.0000e+00 - gen_loss: -100.5707
# Calculating FID score for epoch 79...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - critic_gradient_penalty: 0.0089 - critic_loss: -2.3932 - critic_wassertein_loss: -2.4826 - fid_score: 0.0000e+00 - gen_loss: -100.8163
# Epoch 80/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - critic_gradient_penalty: 0.0093 - critic_loss: -1.7989 - critic_wassertein_loss: -1.8916 - fid_score: 0.0000e+00 - gen_loss: -98.4538
# Calculating FID score for epoch 80...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0089 - critic_loss: -1.8622 - critic_wassertein_loss: -1.9514 - fid_score: 0.0000e+00 - gen_loss: -98.6674
# Epoch 81/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - critic_gradient_penalty: 0.0109 - critic_loss: -2.7857 - critic_wassertein_loss: -2.8947 - fid_score: 0.0000e+00 - gen_loss: -102.9044
# Calculating FID score for epoch 81...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.0111 - critic_loss: -2.7930 - critic_wassertein_loss: -2.9043 - fid_score: 0.0000e+00 - gen_loss: -102.9274
# Epoch 82/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - critic_gradient_penalty: 0.0106 - critic_loss: -2.9393 - critic_wassertein_loss: -3.0456 - fid_score: 0.0000e+00 - gen_loss: -102.8847
# Calculating FID score for epoch 82...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0106 - critic_loss: -2.9001 - critic_wassertein_loss: -3.0065 - fid_score: 0.0000e+00 - gen_loss: -102.6058
# Epoch 83/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - critic_gradient_penalty: 0.0108 - critic_loss: -3.5734 - critic_wassertein_loss: -3.6813 - fid_score: 0.0000e+00 - gen_loss: -102.2363
# Calculating FID score for epoch 83...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0117 - critic_loss: -3.5850 - critic_wassertein_loss: -3.7025 - fid_score: 0.0000e+00 - gen_loss: -102.2848
# Epoch 84/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - critic_gradient_penalty: 0.0182 - critic_loss: -4.1855 - critic_wassertein_loss: -4.3677 - fid_score: 0.0000e+00 - gen_loss: -104.1299
# Calculating FID score for epoch 84...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.0189 - critic_loss: -4.1840 - critic_wassertein_loss: -4.3726 - fid_score: 0.0000e+00 - gen_loss: -104.0326
# Epoch 85/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - critic_gradient_penalty: 0.0183 - critic_loss: -4.1636 - critic_wassertein_loss: -4.3463 - fid_score: 0.0000e+00 - gen_loss: -98.5636
# Calculating FID score for epoch 85...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0191 - critic_loss: -4.1945 - critic_wassertein_loss: -4.3857 - fid_score: 0.0000e+00 - gen_loss: -98.4971
# Epoch 86/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - critic_gradient_penalty: 0.0388 - critic_loss: -5.3165 - critic_wassertein_loss: -5.7048 - fid_score: 0.0000e+00 - gen_loss: -100.0521
# Calculating FID score for epoch 86...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.0393 - critic_loss: -5.3377 - critic_wassertein_loss: -5.7312 - fid_score: 0.0000e+00 - gen_loss: -99.8512
# Epoch 87/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - critic_gradient_penalty: 0.0601 - critic_loss: -5.8131 - critic_wassertein_loss: -6.4146 - fid_score: 0.0000e+00 - gen_loss: -93.0331
# Calculating FID score for epoch 87...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.0599 - critic_loss: -5.9009 - critic_wassertein_loss: -6.4995 - fid_score: 0.0000e+00 - gen_loss: -93.2577
# Epoch 88/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668ms/step - critic_gradient_penalty: 0.0877 - critic_loss: -7.3355 - critic_wassertein_loss: -8.2130 - fid_score: 0.0000e+00 - gen_loss: -92.4713
# Calculating FID score for epoch 88...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.0862 - critic_loss: -7.4172 - critic_wassertein_loss: -8.2792 - fid_score: 0.0000e+00 - gen_loss: -92.5704
# Epoch 89/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - critic_gradient_penalty: 0.1281 - critic_loss: -8.0694 - critic_wassertein_loss: -9.3504 - fid_score: 0.0000e+00 - gen_loss: -78.9455
# Calculating FID score for epoch 89...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - critic_gradient_penalty: 0.1247 - critic_loss: -8.1471 - critic_wassertein_loss: -9.3936 - fid_score: 0.0000e+00 - gen_loss: -78.1393
# Epoch 90/500
# ...
# Calculating FID score for epoch 475...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - critic_gradient_penalty: 0.1746 - critic_loss: -9.4608 - critic_wassertein_loss: -11.2068 - fid_score: 0.0000e+00 - gen_loss: 44.0642
# Epoch 476/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - critic_gradient_penalty: 0.2095 - critic_loss: -10.5309 - critic_wassertein_loss: -12.6263 - fid_score: 0.0000e+00 - gen_loss: 52.1231
# Calculating FID score for epoch 476...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - critic_gradient_penalty: 0.2089 - critic_loss: -10.4773 - critic_wassertein_loss: -12.5660 - fid_score: 0.0000e+00 - gen_loss: 52.5903
# Epoch 477/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - critic_gradient_penalty: 0.2025 - critic_loss: -10.1022 - critic_wassertein_loss: -12.1272 - fid_score: 0.0000e+00 - gen_loss: 36.6376
# Calculating FID score for epoch 477...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.2039 - critic_loss: -10.0638 - critic_wassertein_loss: -12.1029 - fid_score: 0.0000e+00 - gen_loss: 36.0929
# Epoch 478/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - critic_gradient_penalty: 0.1920 - critic_loss: -9.2774 - critic_wassertein_loss: -11.1978 - fid_score: 0.0000e+00 - gen_loss: 33.5488
# Calculating FID score for epoch 478...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.1920 - critic_loss: -9.2904 - critic_wassertein_loss: -11.2101 - fid_score: 0.0000e+00 - gen_loss: 34.1314
# Epoch 479/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - critic_gradient_penalty: 0.1635 - critic_loss: -8.9167 - critic_wassertein_loss: -10.5518 - fid_score: 0.0000e+00 - gen_loss: 42.7013
# Calculating FID score for epoch 479...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.1675 - critic_loss: -8.9803 - critic_wassertein_loss: -10.6557 - fid_score: 0.0000e+00 - gen_loss: 43.6226
# Epoch 480/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - critic_gradient_penalty: 0.1834 - critic_loss: -9.2012 - critic_wassertein_loss: -11.0351 - fid_score: 0.0000e+00 - gen_loss: 66.3736
# Calculating FID score for epoch 480...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - critic_gradient_penalty: 0.1824 - critic_loss: -9.1366 - critic_wassertein_loss: -10.9606 - fid_score: 0.0000e+00 - gen_loss: 66.3970
# Epoch 481/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - critic_gradient_penalty: 0.1715 - critic_loss: -8.3547 - critic_wassertein_loss: -10.0699 - fid_score: 0.0000e+00 - gen_loss: 67.5700
# Calculating FID score for epoch 481...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.1671 - critic_loss: -8.3944 - critic_wassertein_loss: -10.0658 - fid_score: 0.0000e+00 - gen_loss: 67.5131
# Epoch 482/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - critic_gradient_penalty: 0.1565 - critic_loss: -9.7254 - critic_wassertein_loss: -11.2900 - fid_score: 0.0000e+00 - gen_loss: 70.6260
# Calculating FID score for epoch 482...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - critic_gradient_penalty: 0.1584 - critic_loss: -9.7371 - critic_wassertein_loss: -11.3209 - fid_score: 0.0000e+00 - gen_loss: 70.2273
# Epoch 483/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - critic_gradient_penalty: 0.1825 - critic_loss: -10.9059 - critic_wassertein_loss: -12.7312 - fid_score: 0.0000e+00 - gen_loss: 76.2833
# Calculating FID score for epoch 483...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.1850 - critic_loss: -10.9459 - critic_wassertein_loss: -12.7957 - fid_score: 0.0000e+00 - gen_loss: 75.9866
# Epoch 484/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - critic_gradient_penalty: 0.2407 - critic_loss: -12.6154 - critic_wassertein_loss: -15.0226 - fid_score: 0.0000e+00 - gen_loss: 72.2901
# Calculating FID score for epoch 484...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - critic_gradient_penalty: 0.2452 - critic_loss: -12.6474 - critic_wassertein_loss: -15.0994 - fid_score: 0.0000e+00 - gen_loss: 72.6343
# Epoch 485/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 603ms/step - critic_gradient_penalty: 0.3017 - critic_loss: -12.6240 - critic_wassertein_loss: -15.6409 - fid_score: 0.0000e+00 - gen_loss: 73.1518
# Calculating FID score for epoch 485...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - critic_gradient_penalty: 0.2982 - critic_loss: -12.7306 - critic_wassertein_loss: -15.7128 - fid_score: 0.0000e+00 - gen_loss: 73.6953
# Epoch 486/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - critic_gradient_penalty: 0.3543 - critic_loss: -12.6101 - critic_wassertein_loss: -16.1533 - fid_score: 0.0000e+00 - gen_loss: 77.8962
# Calculating FID score for epoch 486...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - critic_gradient_penalty: 0.3526 - critic_loss: -12.6289 - critic_wassertein_loss: -16.1546 - fid_score: 0.0000e+00 - gen_loss: 77.7431
# Epoch 487/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - critic_gradient_penalty: 0.2682 - critic_loss: -12.0512 - critic_wassertein_loss: -14.7327 - fid_score: 0.0000e+00 - gen_loss: 68.5138
# Calculating FID score for epoch 487...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.2653 - critic_loss: -11.9761 - critic_wassertein_loss: -14.6294 - fid_score: 0.0000e+00 - gen_loss: 67.6267
# Epoch 488/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 670ms/step - critic_gradient_penalty: 0.2171 - critic_loss: -10.4897 - critic_wassertein_loss: -12.6607 - fid_score: 0.0000e+00 - gen_loss: 49.5219
# Calculating FID score for epoch 488...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - critic_gradient_penalty: 0.2161 - critic_loss: -10.4982 - critic_wassertein_loss: -12.6593 - fid_score: 0.0000e+00 - gen_loss: 49.2160
# Epoch 489/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - critic_gradient_penalty: 0.1741 - critic_loss: -10.9860 - critic_wassertein_loss: -12.7274 - fid_score: 0.0000e+00 - gen_loss: 48.2649
# Calculating FID score for epoch 489...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.1772 - critic_loss: -11.0214 - critic_wassertein_loss: -12.7938 - fid_score: 0.0000e+00 - gen_loss: 48.7892
# Epoch 490/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 646ms/step - critic_gradient_penalty: 0.2250 - critic_loss: -11.5294 - critic_wassertein_loss: -13.7792 - fid_score: 0.0000e+00 - gen_loss: 54.4921
# Calculating FID score for epoch 490...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - critic_gradient_penalty: 0.2263 - critic_loss: -11.5060 - critic_wassertein_loss: -13.7691 - fid_score: 0.0000e+00 - gen_loss: 54.2577
# Epoch 491/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - critic_gradient_penalty: 0.2483 - critic_loss: -11.4813 - critic_wassertein_loss: -13.9643 - fid_score: 0.0000e+00 - gen_loss: 56.4735
# Calculating FID score for epoch 491...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - critic_gradient_penalty: 0.2468 - critic_loss: -11.3830 - critic_wassertein_loss: -13.8513 - fid_score: 0.0000e+00 - gen_loss: 56.2923
# Epoch 492/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - critic_gradient_penalty: 0.1929 - critic_loss: -11.2236 - critic_wassertein_loss: -13.1530 - fid_score: 0.0000e+00 - gen_loss: 48.0096
# Calculating FID score for epoch 492...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.1969 - critic_loss: -11.2823 - critic_wassertein_loss: -13.2512 - fid_score: 0.0000e+00 - gen_loss: 47.6165
# Epoch 493/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - critic_gradient_penalty: 0.2366 - critic_loss: -12.5250 - critic_wassertein_loss: -14.8908 - fid_score: 0.0000e+00 - gen_loss: 40.5532
# Calculating FID score for epoch 493...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.2404 - critic_loss: -12.4591 - critic_wassertein_loss: -14.8629 - fid_score: 0.0000e+00 - gen_loss: 40.4304
# Epoch 494/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - critic_gradient_penalty: 0.2226 - critic_loss: -12.2361 - critic_wassertein_loss: -14.4624 - fid_score: 0.0000e+00 - gen_loss: 38.6344
# Calculating FID score for epoch 494...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.2250 - critic_loss: -12.2152 - critic_wassertein_loss: -14.4653 - fid_score: 0.0000e+00 - gen_loss: 38.2541
# Epoch 495/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - critic_gradient_penalty: 0.2466 - critic_loss: -12.5160 - critic_wassertein_loss: -14.9816 - fid_score: 0.0000e+00 - gen_loss: 38.2087
# Calculating FID score for epoch 495...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.2486 - critic_loss: -12.5166 - critic_wassertein_loss: -15.0022 - fid_score: 0.0000e+00 - gen_loss: 38.8654
# Epoch 496/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - critic_gradient_penalty: 0.2815 - critic_loss: -12.7667 - critic_wassertein_loss: -15.5817 - fid_score: 0.0000e+00 - gen_loss: 46.5791
# Calculating FID score for epoch 496...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.2781 - critic_loss: -12.7864 - critic_wassertein_loss: -15.5671 - fid_score: 0.0000e+00 - gen_loss: 46.6494
# Epoch 497/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - critic_gradient_penalty: 0.2912 - critic_loss: -13.1258 - critic_wassertein_loss: -16.0382 - fid_score: 0.0000e+00 - gen_loss: 52.6667
# Calculating FID score for epoch 497...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.2943 - critic_loss: -13.0049 - critic_wassertein_loss: -15.9479 - fid_score: 0.0000e+00 - gen_loss: 53.0027
# Epoch 498/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - critic_gradient_penalty: 0.2185 - critic_loss: -11.6992 - critic_wassertein_loss: -13.8844 - fid_score: 0.0000e+00 - gen_loss: 55.2245
# Calculating FID score for epoch 498...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - critic_gradient_penalty: 0.2197 - critic_loss: -11.7254 - critic_wassertein_loss: -13.9224 - fid_score: 0.0000e+00 - gen_loss: 54.6327
# Epoch 499/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - critic_gradient_penalty: 0.2623 - critic_loss: -12.3435 - critic_wassertein_loss: -14.9664 - fid_score: 0.0000e+00 - gen_loss: 44.1392
# Calculating FID score for epoch 499...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.2627 - critic_loss: -12.4040 - critic_wassertein_loss: -15.0309 - fid_score: 0.0000e+00 - gen_loss: 44.0858
# Epoch 500/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - critic_gradient_penalty: 0.3181 - critic_loss: -12.7091 - critic_wassertein_loss: -15.8899 - fid_score: 0.0000e+00 - gen_loss: 48.4660
# Calculating FID score for epoch 500...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# FID Score: nan
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - critic_gradient_penalty: 0.3147 - critic_loss: -12.7282 - critic_wassertein_loss: -15.8747 - fid_score: 0.0000e+00 - gen_loss: 49.2269
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/critic_gradient_penalty</td><td>█▁▁▁▁▁▁▁▁▁▄▂▂▂▂▂▂▂▂▁▁▁▁▂▁▂▂▂▂▂▂▂▂▂▂▂▃▂▂▂</td></tr><tr><td>epoch/critic_loss</td><td>███▄▅▃▂▂▁▁▂▃▃▄▄▄▅▅▅▅▅▅▅▅▅▄▅▅▄▄▄▄▄▄▄▄▄▄▄▃</td></tr><tr><td>epoch/critic_wassertein_loss</td><td>▁▅▆████▇▅▆▇██████▇██▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▆▇▆▇▇</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>epoch/fid_score</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/gen_loss</td><td>▅▁▂▂▂▃▂▄▆▅▆▆▆▆▅▇▆▆▇▆▆▆▆▅▅▆▅▆▆▆▇▆▆▆▇▆█▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/critic_gradient_penalty</td><td>0.30095</td></tr><tr><td>epoch/critic_loss</td><td>-12.80465</td></tr><tr><td>epoch/critic_wassertein_loss</td><td>-15.81412</td></tr><tr><td>epoch/epoch</td><td>499</td></tr><tr><td>epoch/fid_score</td><td>0</td></tr><tr><td>epoch/gen_loss</td><td>52.27059</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch_fid_score</td><td>nan</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DC-GAN-Music</strong> at: <a href='https://wandb.ai/vedantgade2006-secant/DC-GAN-Music/runs/ww4t5tg4' target="_blank">https://wandb.ai/vedantgade2006-secant/DC-GAN-Music/runs/ww4t5tg4</a><br> View project at: <a href='https://wandb.ai/vedantgade2006-secant/DC-GAN-Music' target="_blank">https://wandb.ai/vedantgade2006-secant/DC-GAN-Music</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251002_162712-ww4t5tg4/logs</code>

# %%
# Generate new scores

def generate_new_scores(noise_vector, mode: str, file_name: str, num_scores: int = 1):
    np.random.seed(10752)
    # Create all base random latent vectors
    random_chords = np.random.normal(size=(num_scores, Z_DIM))
    random_style = np.random.normal(size=(num_scores, Z_DIM))
    random_melody = np.random.normal(size=(num_scores, N_TRACKS, Z_DIM))
    random_groove = np.random.normal(size=(num_scores, N_TRACKS, Z_DIM))

    # Replace the specific latent vector based on the mode
    if mode == 'chords':
        chords_lv = noise_vector
        style_lv = random_style
        melody_lv = random_melody
        groove_lv = random_groove

    elif mode == 'style':
        chords_lv = random_chords
        style_lv = noise_vector
        melody_lv = random_melody
        groove_lv = random_groove

    elif mode == 'melody':
        chords_lv = random_chords
        style_lv = random_style
        melody_lv = noise_vector
        groove_lv = random_groove

    elif mode == 'groove':
        chords_lv = random_chords
        style_lv = random_style
        melody_lv = random_melody
        groove_lv = noise_vector

    else:
        raise ValueError(f"Mode should be either of: chords, style, melody, groove. Got {mode} instead.")

    # Assemble the latent vectors in the correct order for the generator
    latent_vectors = [chords_lv, style_lv, melody_lv, groove_lv]
    print(f"{mode} latent noise vector has been generated!")


    generated_music_scores = gen_model(latent_vectors).numpy()

    # Select the first generated score for plotting and MIDI conversion
    generated_music_score = generated_music_scores[0]

    plot_score(generated_music_score)
    notes_to_midi(generated_music_scores, N_BARS, N_TRACKS, N_STEPS_PER_BAR, f"{file_name}")



chords_change = np.random.normal(size=(1, Z_DIM))
generate_new_scores(chords_change, "chords", "changed_chord_midi", 2)

style_change = np.random.normal(size=(1, Z_DIM))
generate_new_scores(style_change, "style", "changed_style_midi", 2)

melody_change = np.random.normal(size=(1, N_TRACKS, Z_DIM))
generate_new_scores(melody_change, "melody", "changed_melody_midi", 2)

groove_change = np.random.normal(size=(1, N_TRACKS, Z_DIM))
generate_new_scores(groove_change, "groove", "changed_groove_midi", 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1486413584.py in <cell line: 0>()
#      52
#      53
# ---> 54 chords_change = np.random.normal(size=(1, Z_DIM))
#      55 generate_new_scores(chords_change, "chords", "changed_chord_midi", 2)
#      56
#
# NameError: name 'np' is not defined

# %%
import tensorflow as tf

# List all available physical devices
physical_devices = tf.config.list_physical_devices()
print("Available devices:", physical_devices)

# Check if a GPU is available
gpu_available = tf.config.list_physical_devices('GPU')
if gpu_available:
    print("GPU is available and will be used by TensorFlow.")
else:
    print("No GPU available. TensorFlow will use the CPU.")
# Out:
# Available devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU is available and will be used by TensorFlow.
# Available devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU is available and will be used by TensorFlow.
